# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Sahil\OneDrive\Documents\test.csv")

# %%
df.head()
# Out:
#    Class Index                                              Title  \
# 0            3                  Fears for T N pension after talks
# 1            4  The Race is On: Second Private Team Sets Launc...
# 2            4      Ky. Company Wins Grant to Study Peptides (AP)
# 3            4      Prediction Unit Helps Forecast Wildfires (AP)
# 4            4        Calif. Aims to Limit Farm-Related Smog (AP)
#
#                                          Description
# 0  Unions representing workers at Turner   Newall...
# 1  SPACE.com - TORONTO, Canada -- A second\team o...
# 2  AP - A company founded by a chemistry research...
# 3  AP - It's barely dawn when Mike Fitzpatrick st...
# 4  AP - Southern California's smog-fighting agenc...

# %%
df['Class Index']= df['Class Index'].replace(1, 'World')

# %%
df['Class Index']= df['Class Index'].replace(2, 'Sports')
df['Class Index']= df['Class Index'].replace(3, 'Business')
df['Class Index']= df['Class Index'].replace(4, 'Sci/Tech')

# %%
df['Class Index']
# Out:
# 0       Business
# 1       Sci/Tech
# 2       Sci/Tech
# 3       Sci/Tech
# 4       Sci/Tech
#           ...
# 7595       World
# 7596      Sports
# 7597      Sports
# 7598    Business
# 7599    Business
# Name: Class Index, Length: 7600, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7600 entries, 0 to 7599
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Class Index  7600 non-null   object
#  1   Title        7600 non-null   object
#  2   Description  7600 non-null   object
# dtypes: object(3)
# memory usage: 178.3+ KB

# %%
df.shape
# Out:
# (7600, 3)

# %%
df.isnull().sum()
# Out:
# Class Index    0
# Title          0
# Description    0
# dtype: int64

# %%
df['Class Index'].value_counts()
# Out:
# Class Index
# Business    1900
# Sci/Tech    1900
# Sports      1900
# World       1900
# Name: count, dtype: int64

# %%
import nltk

# %%
df['num_chr']=df["Description"].apply(len)

# %%
df['num_words']=df['Description'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#   Class Index                                              Title  \
# 0    Business                  Fears for T N pension after talks
# 1    Sci/Tech  The Race is On: Second Private Team Sets Launc...
# 2    Sci/Tech      Ky. Company Wins Grant to Study Peptides (AP)
# 3    Sci/Tech      Prediction Unit Helps Forecast Wildfires (AP)
# 4    Sci/Tech        Calif. Aims to Limit Farm-Related Smog (AP)
#
#                                          Description  num_chr  num_words
# 0  Unions representing workers at Turner   Newall...      127         20
# 1  SPACE.com - TORONTO, Canada -- A second\team o...      234         41
# 2  AP - A company founded by a chemistry research...      214         40
# 3  AP - It's barely dawn when Mike Fitzpatrick st...      272         56
# 4  AP - Southern California's smog-fighting agenc...      179         31

# %%
plt.figure(figsize=(12,4))
sns.histplot(df[df['Class Index']=='World']['num_chr'],color='y',bins=10)
# Out:
# <Axes: xlabel='num_chr', ylabel='Count'>

# %%
sns.histplot(df[df['Class Index']=='Business']['num_chr'] ,color= 'r',bins=10)
# Out:
# <Axes: xlabel='num_chr', ylabel='Count'>

# %%
sns.histplot(df[df['Class Index']=='Sci/Tech']['num_chr'],color='g',bins=10)
# Out:
# <Axes: xlabel='num_chr', ylabel='Count'>

# %%
sns.histplot(df[df['Class Index']=='Sports']['num_chr'] , color= 'b',bins=10)
# Out:
# <Axes: xlabel='num_chr', ylabel='Count'>

# %%
df1=df.drop(columns=['Title','Description'])

# %%
from sklearn.preprocessing import LabelEncoder
encoder=  LabelEncoder()
df1['Class Index']=encoder .fit_transform(df["Class Index"])

# %%
df1.head()
# Out:
#    Class Index  num_chr  num_words
# 0            0      127         20
# 1            1      234         41
# 2            1      214         40
# 3            1      272         56
# 4            1      179         31

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df1.corr() , annot=True , square=True)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (7600, 5)

# %%
df.drop(columns=['Title'])
# Out:
#      Class Index                                        Description  num_chr  \
# 0       Business  Unions representing workers at Turner   Newall...      127
# 1       Sci/Tech  SPACE.com - TORONTO, Canada -- A second\team o...      234
# 2       Sci/Tech  AP - A company founded by a chemistry research...      214
# 3       Sci/Tech  AP - It's barely dawn when Mike Fitzpatrick st...      272
# 4       Sci/Tech  AP - Southern California's smog-fighting agenc...      179
# ...          ...                                                ...      ...
# 7595       World  Ukrainian presidential candidate Viktor Yushch...      183
# 7596      Sports  With the supply of attractive pitching options...      345
# 7597      Sports  Like Roger Clemens did almost exactly eight ye...      156
# 7598    Business  SINGAPORE : Doctors in the United States have ...      166
# 7599    Business  EBay plans to buy the apartment and home renta...      138
#
#       num_words
# 0            20
# 1            41
# 2            40
# 3            56
# 4            31
# ...         ...
# 7595         30
# 7596         66
# 7597         28
# 7598         27
# 7599         26
#
# [7600 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df['Description'],df['Class Index'],test_size=0.3,random_state=5)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = Pipeline([('tfidf' , TfidfVectorizer()), ('classifer' , RandomForestClassifier(n_estimators=100))])

# %%
classifier.fit(x_train , y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classifer', RandomForestClassifier())])

# %%
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix

# %%
def acc(y_pred , y_test):
  print(accuracy_score(y_pred , y_test))
  print(classification_report(y_pred , y_test))
  print(confusion_matrix(y_pred , y_test))

# %%
y_pre = classifier.predict(x_test)

# %%
acc(y_pre , y_test)
# Out:
# 0.8171052631578948
#               precision    recall  f1-score   support
#
#     Business       0.75      0.80      0.77       535
#     Sci/Tech       0.79      0.78      0.78       569
#       Sports       0.94      0.84      0.89       646
#        World       0.79      0.84      0.82       530
#
#     accuracy                           0.82      2280
#    macro avg       0.82      0.82      0.82      2280
# weighted avg       0.82      0.82      0.82      2280
#
# [[428  64  10  33]
#  [ 80 445  13  31]
#  [ 24  24 545  53]
#  [ 40  32  13 445]]

# %%
classifier.predict(['The team scored two goals in the final five minutes to win the match.'])
# Out:
# array(['Sports'], dtype=object)
